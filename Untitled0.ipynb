# %% [markdown]
# <a href="https://colab.research.google.com/github/SangBejoo/AIMLABTEST/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets list
! kaggle datasets download -d mateuszbuda/lgg-mri-segmentation
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# ref                                                               title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# alphiree/cardiovascular-diseases-risk-prediction-dataset          Cardiovascular Diseases Risk Prediction Dataset       5MB  2023-07-03 12:12:19           2202         94  1.0
# nelgiriyewithana/countries-of-the-world-2023                      Global Country Information Dataset 2023              23KB  2023-07-08 20:37:33           1116         52  1.0
# shuvammandal121/9000-companies-and-its-ratings-dataset            9000 companies and its ratings dataset              202KB  2023-07-12 04:52:05            579         29  1.0
# arnavsmayan/netflix-userbase-dataset                              Netflix Userbase Dataset                             25KB  2023-07-04 07:38:41           2315         55  1.0
# aaditshukla/flipkart-fasion-products-dataset                       Ecommerce Product dataset                           15MB  2023-07-04 05:44:07            833         28  0.9411765
# iamsouravbanerjee/data-science-salaries-2023                      Data Science Salaries: 2020-2023                     32KB  2023-07-07 12:53:23           1157         53  1.0
# arthurchongg/imdb-top-1000-movies                                 IMDB Top 1000 Movies                                 64KB  2023-07-08 03:43:13           1100         37  1.0
# tawfikelmetwally/automobile-dataset                               Car information dataset                               6KB  2023-05-28 18:26:48           8600        224  0.9411765
# slmsshk/bollywood-release-movie-dataset                           Bollywood movie box office collection Dataset        62KB  2023-07-01 14:55:06            415         27  0.9411765
# dansbecker/melbourne-housing-snapshot                             Melbourne Housing Snapshot                          451KB  2018-06-05 12:52:24         120366       1301  0.7058824
# mohithsairamreddy/salary-data                                     Salary_Data                                          17KB  2023-05-18 14:05:19          11535        234  0.88235295
# iottech/electric-vehicle-data-1997-2024-update-version            Electric Vehicle Data (1997-2024) (update version)    4MB  2023-06-25 14:04:27           1169         37  0.9411765
# nelgiriyewithana/mcdonalds-store-reviews                          McDonald's Store Reviews                              2MB  2023-06-19 08:46:00           1906         48  1.0
# amirhosseinmirzaie/diamonds-price-dataset                         Diamonds Price Dataset                              557KB  2023-06-08 08:19:03            542         36  1.0
# drahulsingh/david-warner-all-international-cricket-centuries      David-Warner-All-International-Cricket-Centuries      1KB  2023-07-02 15:04:16            277         28  1.0
# amirhosseinmirzaie/countries-life-expectancy                      Countries Life Expectancy                            88KB  2023-06-30 07:17:04            936         41  1.0
# ibrahimonmars/cnn-youtube-titles-views-and-posting-dates-dataset  CNN YouTube: Titles, Views & Posting Dates Dataset   38KB  2023-07-03 18:45:41            290         27  1.0
# rajkumarpandey02/2023-world-population-by-country                  World Population by Country                         38KB  2023-06-01 06:10:41           4632         97  1.0
# drahulsingh/largest-malls                                         Largest-Malls                                         2KB  2023-06-26 17:25:56            594         30  1.0
# wspirat/germany-used-cars-dataset-2023                            Germany Used Cars Dataset 2023                        7MB  2023-06-24 18:53:56            924         30  1.0
# lgg-mri-segmentation.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import pandas as pd
import numpy as np
import matplotlib as mtp
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow import keras
import tensorflow as tf

# %%
import zipfile
from glob import glob

# Extract the zip file
zip_path = 'lgg-mri-segmentation.zip'  # Replace with the path to your downloaded zip file
extract_dir = 'Datasets'
# Replace with the path to the folder where you want to extract the files

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# Load image filenames
image_filenames_train = []

# Update the path to the extracted folder
mask_files = glob('/content/Datasets/kaggle_3m/*/*_mask*')

for i in mask_files:
    image_filenames_train.append(i.replace('_mask', ''))

# Verify the loaded filenames
print(image_filenames_train[:10])

# Check the number of loaded filenames
print(len(image_filenames_train))
# Out:
# ['/content/Datasets/kaggle_3m/TCGA_DU_7294_19890104/TCGA_DU_7294_19890104_12.tif', '/content/Datasets/kaggle_3m/TCGA_DU_7294_19890104/TCGA_DU_7294_19890104_17.tif', '/content/Datasets/kaggle_3m/TCGA_DU_7294_19890104/TCGA_DU_7294_19890104_26.tif', '/content/Datasets/kaggle_3m/TCGA_DU_7294_19890104/TCGA_DU_7294_19890104_19.tif', '/content/Datasets/kaggle_3m/TCGA_DU_7294_19890104/TCGA_DU_7294_19890104_6.tif', '/content/Datasets/kaggle_3m/TCGA_DU_7294_19890104/TCGA_DU_7294_19890104_28.tif', '/content/Datasets/kaggle_3m/TCGA_DU_7294_19890104/TCGA_DU_7294_19890104_18.tif', '/content/Datasets/kaggle_3m/TCGA_DU_7294_19890104/TCGA_DU_7294_19890104_29.tif', '/content/Datasets/kaggle_3m/TCGA_DU_7294_19890104/TCGA_DU_7294_19890104_16.tif', '/content/Datasets/kaggle_3m/TCGA_DU_7294_19890104/TCGA_DU_7294_19890104_31.tif']
# 3929

# %%
from glob import glob

msk_paths = glob('../content/Datasets/kaggle_3m/*/*_mask*')
img_paths = [m.replace('_mask','') for m in msk_paths]

# %%
import cv2

rows, cols = 10, 2

fig = plt.figure(figsize = (4, 20))
for i in range(1, rows*cols, 2):

    fig.add_subplot(rows, cols, i)
    img = cv2.imread(img_paths[i])
    plt.imshow(img)

    fig.add_subplot(rows, cols, i+1)
    msk = cv2.imread(msk_paths[i])
    plt.imshow(msk)

# %%
mri_df = pd.DataFrame({'img':img_paths,
                       'msk':msk_paths})
mri_df.head()
# Out:
#                                                  img  \
# 0  ../content/Datasets/kaggle_3m/TCGA_DU_7294_198...
# 1  ../content/Datasets/kaggle_3m/TCGA_DU_7294_198...
# 2  ../content/Datasets/kaggle_3m/TCGA_DU_7294_198...
# 3  ../content/Datasets/kaggle_3m/TCGA_DU_7294_198...
# 4  ../content/Datasets/kaggle_3m/TCGA_DU_7294_198...
#
#                                                  msk
# 0  ../content/Datasets/kaggle_3m/TCGA_DU_7294_198...
# 1  ../content/Datasets/kaggle_3m/TCGA_DU_7294_198...
# 2  ../content/Datasets/kaggle_3m/TCGA_DU_7294_198...
# 3  ../content/Datasets/kaggle_3m/TCGA_DU_7294_198...
# 4  ../content/Datasets/kaggle_3m/TCGA_DU_7294_198...

# %%
from sklearn.model_selection import train_test_split

mri_df_train, mri_df_test = train_test_split(mri_df, test_size = 0.1,random_state=77_47)
mri_df_train, mri_df_val = train_test_split(mri_df_train, test_size = 0.1,random_state=77_47)

mri_df_train = mri_df_train.reset_index(drop=True)
mri_df_val = mri_df_val.reset_index(drop=True)
mri_df_test = mri_df_test.reset_index(drop=True)

# %%
print(mri_df_train.shape,
      mri_df_val.shape,
      mri_df_test.shape)
# Out:
# (3182, 2) (354, 2) (393, 2)

# %%
from keras.preprocessing.image import ImageDataGenerator

# assuming an human precision of 1% for manual tasks, so I'll use 2% for a safaty error margin
BATCH_SIZE = 32

def transformator(df,
                  rotation_range=0.2,
                  width_shift_range=0.02,
                  height_shift_range=0.02,
                  shear_range=0.1,
                  zoom_range=0.1,
                  horizontal_flip=True,
                  IMG_SIZE_TRAIN = (128,128),
                  BATCH_SIZE = 32):

  img_datag = ImageDataGenerator(
                rotation_range=rotation_range,
                width_shift_range=width_shift_range,
                height_shift_range=height_shift_range,
                shear_range=shear_range,
                zoom_range=zoom_range,
                horizontal_flip=True,
                fill_mode='nearest')

  msk_datag = ImageDataGenerator(
                rotation_range=rotation_range,
                width_shift_range=width_shift_range,
                height_shift_range=height_shift_range,
                shear_range=shear_range,
                zoom_range=zoom_range,
                horizontal_flip=True,
                fill_mode='nearest')

  img_generated = img_datag.flow_from_dataframe(
                      df,
                      x_col = 'img',
                      class_mode = None,
                      color_mode = 'rgb',
                      target_size = IMG_SIZE_TRAIN,
                      batch_size = BATCH_SIZE,
                      save_to_dir = None,
                      save_prefix = 'image',
                      seed = 777447)

  msk_generated = msk_datag.flow_from_dataframe(
                      df,
                      x_col='msk',
                      class_mode=None,
                      color_mode='grayscale',
                      target_size=IMG_SIZE_TRAIN,
                      batch_size=BATCH_SIZE,
                      save_to_dir=None,
                      save_prefix='mask',
                      seed=777447)

  generated = zip(img_generated, msk_generated)

  for img, msk in generated:
      img = img / 255
      msk = msk / 255

      msk[msk > 0.5] = 1
      msk[msk <= 0.5] = 0

      yield (img,msk)

data_train = transformator(mri_df_train)
data_val = transformator(mri_df_val)
data_test = transformator(mri_df_test)

# %%
import keras.layers as ls
import keras

inp = ls.Input((128,128,3))

c1 = ls.Conv2D(32, (3, 3),padding='same')(inp)
b1 = ls.Activation('relu')(c1)
c1 = ls.Conv2D(32, (3, 3), padding='same')(b1)
b1 = ls.BatchNormalization(axis=3)(c1)
b1 = ls.Activation('relu')(b1)
p1 = ls.MaxPooling2D(pool_size=(2, 2))(b1)

c2 = ls.Conv2D(64, (3,3),padding='same')(p1)
b2 = ls.Activation('relu')(c2)
c2 = ls.Conv2D(64, (3, 3), padding='same')(b2)
b2 = ls.BatchNormalization(axis=3)(c2)
b2 = ls.Activation('relu')(b2)
p2 = ls.MaxPooling2D(pool_size=(2, 2))(b2)

c3 = ls.Conv2D(128, (3,3),padding='same')(p2)
b3 = ls.Activation('relu')(c3)
c3 = ls.Conv2D(128, (3, 3), padding='same')(b3)
b3 = ls.BatchNormalization(axis=3)(c3)
b3 = ls.Activation('relu')(b3)
p3 = ls.MaxPooling2D(pool_size=(2, 2))(b3)

c4 = ls.Conv2D(256, (3,3),padding='same')(p3)
b4 = ls.Activation('relu')(c4)
c4 = ls.Conv2D(256, (3, 3), padding='same')(b4)
b4 = ls.BatchNormalization(axis=3)(c4)
b4 = ls.Activation('relu')(b4)
p4 = ls.MaxPooling2D(pool_size=(2, 2))(b4)

c5 = ls.Conv2D(512, (3,3),padding='same')(p4)
b5 = ls.Activation('relu')(c5)
c5 = ls.Conv2D(512, (3, 3), padding='same')(b5)
b5 = ls.BatchNormalization(axis=3)(c5)
b5 = ls.Activation('relu')(b5)
p5 = ls.MaxPooling2D(pool_size=(2, 2))(b5)

u6 = ls.concatenate([ls.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(b5), c4], axis=3)
c6 = ls.Conv2D(256, (3, 3), padding='same')(u6)
b6 = ls.Activation('relu')(c6)
c6 = ls.Conv2D(256, (3, 3), padding='same')(b6)
b6 = ls.BatchNormalization(axis=3)(c6)
b6 = ls.Activation('relu')(b6)

u7 = ls.concatenate([ls.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(b6), c3], axis=3)
c7 = ls.Conv2D(128, (3, 3), padding='same')(u7)
b7 = ls.Activation('relu')(c7)
c7 = ls.Conv2D(128, (3, 3), padding='same')(b7)
b7 = ls.BatchNormalization(axis=3)(c7)
b7 = ls.Activation('relu')(b7)

u8 = ls.concatenate([ls.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(b7), c2], axis=3)
c8 = ls.Conv2D(64, (3, 3), padding='same')(u8)
b8 = ls.Activation('relu')(c8)
c8 = ls.Conv2D(64, (3, 3), padding='same')(b8)
b8 = ls.BatchNormalization(axis=3)(c8)
b8 = ls.Activation('relu')(b8)

u9 = ls.concatenate([ls.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(b8), c1], axis=3)
c9 = ls.Conv2D(32, (3, 3), padding='same')(u9)
b9 = ls.Activation('relu')(c9)
c9 = ls.Conv2D(32, (3, 3), padding='same')(b9)
b9 = ls.BatchNormalization(axis=3)(c9)
b9 = ls.Activation('relu')(b9)

c10 = ls.Conv2D(1, (1, 1), activation='sigmoid')(b9)

model = keras.Model(inputs=[inp],
                    outputs=[c10])

# %%
import keras.backend as K

smooth=100

def dice_coef(y_true, y_pred):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)

    intersec = K.sum(y_true * y_pred)
    mod_sum = K.sum(y_true) + K.sum(y_pred)

    return (2 * intersec + smooth) / (mod_sum + smooth)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def iou(y_true, y_pred):
    intersec = K.sum(y_true * y_pred)
    comb_area = K.sum(y_true + y_pred) - intersec

    return (intersec + smooth) / (comb_area + smooth)

def iou_loss(y_true, y_pred):
  return - iou(y_true, y_pred)

# %%
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam

model.compile(optimizer = Adam(learning_rate=0.0001),
              loss = iou_loss,
              metrics=["binary_accuracy", iou, dice_coef])


history = model.fit(data_train,
                    steps_per_epoch=(len(mri_df_train) / BATCH_SIZE),
                    epochs=20,
                    callbacks=[ModelCheckpoint('unet_128_mri_seg.hdf5', verbose=1, save_best_only=True)],
                    validation_data = data_val,
                    validation_steps=len(mri_df_val) / BATCH_SIZE)
# Out:
# Found 3182 validated image filenames.
# Found 3182 validated image filenames.
# Epoch 1/20
# 100/99 [==============================] - ETA: 0s - loss: -0.0290 - binary_accuracy: 0.8417 - iou: 0.0291 - dice_coef: 0.0557Found 354 validated image filenames.
# Found 354 validated image filenames.
#
# Epoch 1: val_loss improved from inf to -0.01297, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 65s 419ms/step - loss: -0.0290 - binary_accuracy: 0.8417 - iou: 0.0291 - dice_coef: 0.0557 - val_loss: -0.0130 - val_binary_accuracy: 0.9875 - val_iou: 0.0125 - val_dice_coef: 0.0237
# Epoch 2/20
# 100/99 [==============================] - ETA: 0s - loss: -0.0395 - binary_accuracy: 0.9595 - iou: 0.0396 - dice_coef: 0.0751
# Epoch 2: val_loss did not improve from -0.01297
# 99/99 [==============================] - 37s 378ms/step - loss: -0.0395 - binary_accuracy: 0.9595 - iou: 0.0396 - dice_coef: 0.0751 - val_loss: -0.0128 - val_binary_accuracy: 0.9878 - val_iou: 0.0126 - val_dice_coef: 0.0234
# Epoch 3/20
# 100/99 [==============================] - ETA: 0s - loss: -0.0453 - binary_accuracy: 0.9754 - iou: 0.0453 - dice_coef: 0.0856
# Epoch 3: val_loss improved from -0.01297 to -0.02237, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 36s 361ms/step - loss: -0.0453 - binary_accuracy: 0.9754 - iou: 0.0453 - dice_coef: 0.0856 - val_loss: -0.0224 - val_binary_accuracy: 0.9882 - val_iou: 0.0227 - val_dice_coef: 0.0424
# Epoch 4/20
# 100/99 [==============================] - ETA: 0s - loss: -0.0508 - binary_accuracy: 0.9791 - iou: 0.0508 - dice_coef: 0.0953
# Epoch 4: val_loss improved from -0.02237 to -0.03766, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 36s 362ms/step - loss: -0.0508 - binary_accuracy: 0.9791 - iou: 0.0508 - dice_coef: 0.0953 - val_loss: -0.0377 - val_binary_accuracy: 0.9895 - val_iou: 0.0469 - val_dice_coef: 0.0858
# Epoch 5/20
# 100/99 [==============================] - ETA: 0s - loss: -0.0573 - binary_accuracy: 0.9834 - iou: 0.0576 - dice_coef: 0.1074
# Epoch 5: val_loss improved from -0.03766 to -0.06635, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 36s 364ms/step - loss: -0.0573 - binary_accuracy: 0.9834 - iou: 0.0576 - dice_coef: 0.1074 - val_loss: -0.0663 - val_binary_accuracy: 0.9891 - val_iou: 0.0707 - val_dice_coef: 0.1295
# Epoch 6/20
# 100/99 [==============================] - ETA: 0s - loss: -0.0652 - binary_accuracy: 0.9866 - iou: 0.0653 - dice_coef: 0.1207
# Epoch 6: val_loss improved from -0.06635 to -0.07986, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 33s 336ms/step - loss: -0.0652 - binary_accuracy: 0.9866 - iou: 0.0653 - dice_coef: 0.1207 - val_loss: -0.0799 - val_binary_accuracy: 0.9737 - val_iou: 0.0759 - val_dice_coef: 0.1365
# Epoch 7/20
# 100/99 [==============================] - ETA: 0s - loss: -0.0761 - binary_accuracy: 0.9895 - iou: 0.0760 - dice_coef: 0.1394
# Epoch 7: val_loss improved from -0.07986 to -0.11659, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 36s 365ms/step - loss: -0.0761 - binary_accuracy: 0.9895 - iou: 0.0760 - dice_coef: 0.1394 - val_loss: -0.1166 - val_binary_accuracy: 0.9917 - val_iou: 0.1247 - val_dice_coef: 0.2177
# Epoch 8/20
# 100/99 [==============================] - ETA: 0s - loss: -0.0869 - binary_accuracy: 0.9892 - iou: 0.0867 - dice_coef: 0.1571
# Epoch 8: val_loss improved from -0.11659 to -0.12636, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 34s 345ms/step - loss: -0.0869 - binary_accuracy: 0.9892 - iou: 0.0867 - dice_coef: 0.1571 - val_loss: -0.1264 - val_binary_accuracy: 0.9901 - val_iou: 0.1381 - val_dice_coef: 0.2366
# Epoch 9/20
# 100/99 [==============================] - ETA: 0s - loss: -0.1009 - binary_accuracy: 0.9903 - iou: 0.1013 - dice_coef: 0.1811
# Epoch 9: val_loss improved from -0.12636 to -0.14817, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 34s 345ms/step - loss: -0.1009 - binary_accuracy: 0.9903 - iou: 0.1013 - dice_coef: 0.1811 - val_loss: -0.1482 - val_binary_accuracy: 0.9884 - val_iou: 0.1511 - val_dice_coef: 0.2573
# Epoch 10/20
# 100/99 [==============================] - ETA: 0s - loss: -0.1202 - binary_accuracy: 0.9923 - iou: 0.1205 - dice_coef: 0.2118
# Epoch 10: val_loss improved from -0.14817 to -0.17508, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 36s 361ms/step - loss: -0.1202 - binary_accuracy: 0.9923 - iou: 0.1205 - dice_coef: 0.2118 - val_loss: -0.1751 - val_binary_accuracy: 0.9934 - val_iou: 0.1666 - val_dice_coef: 0.2760
# Epoch 11/20
# 100/99 [==============================] - ETA: 0s - loss: -0.1429 - binary_accuracy: 0.9926 - iou: 0.1429 - dice_coef: 0.2463
# Epoch 11: val_loss improved from -0.17508 to -0.18865, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 36s 360ms/step - loss: -0.1429 - binary_accuracy: 0.9926 - iou: 0.1429 - dice_coef: 0.2463 - val_loss: -0.1887 - val_binary_accuracy: 0.9926 - val_iou: 0.1797 - val_dice_coef: 0.2917
# Epoch 12/20
# 100/99 [==============================] - ETA: 0s - loss: -0.1732 - binary_accuracy: 0.9942 - iou: 0.1738 - dice_coef: 0.2909
# Epoch 12: val_loss improved from -0.18865 to -0.22476, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 34s 342ms/step - loss: -0.1732 - binary_accuracy: 0.9942 - iou: 0.1738 - dice_coef: 0.2909 - val_loss: -0.2248 - val_binary_accuracy: 0.9887 - val_iou: 0.2115 - val_dice_coef: 0.3377
# Epoch 13/20
# 100/99 [==============================] - ETA: 0s - loss: -0.2081 - binary_accuracy: 0.9949 - iou: 0.2082 - dice_coef: 0.3394
# Epoch 13: val_loss improved from -0.22476 to -0.27503, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 36s 366ms/step - loss: -0.2081 - binary_accuracy: 0.9949 - iou: 0.2082 - dice_coef: 0.3394 - val_loss: -0.2750 - val_binary_accuracy: 0.9901 - val_iou: 0.2612 - val_dice_coef: 0.3973
# Epoch 14/20
# 100/99 [==============================] - ETA: 0s - loss: -0.2460 - binary_accuracy: 0.9950 - iou: 0.2462 - dice_coef: 0.3882
# Epoch 14: val_loss improved from -0.27503 to -0.33841, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 34s 344ms/step - loss: -0.2460 - binary_accuracy: 0.9950 - iou: 0.2462 - dice_coef: 0.3882 - val_loss: -0.3384 - val_binary_accuracy: 0.9935 - val_iou: 0.3241 - val_dice_coef: 0.4689
# Epoch 15/20
# 100/99 [==============================] - ETA: 0s - loss: -0.2972 - binary_accuracy: 0.9960 - iou: 0.2972 - dice_coef: 0.4518
# Epoch 15: val_loss improved from -0.33841 to -0.36365, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 36s 361ms/step - loss: -0.2972 - binary_accuracy: 0.9960 - iou: 0.2972 - dice_coef: 0.4518 - val_loss: -0.3637 - val_binary_accuracy: 0.9948 - val_iou: 0.3843 - val_dice_coef: 0.5440
# Epoch 16/20
# 100/99 [==============================] - ETA: 0s - loss: -0.3453 - binary_accuracy: 0.9963 - iou: 0.3451 - dice_coef: 0.5051
# Epoch 16: val_loss improved from -0.36365 to -0.39603, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 33s 335ms/step - loss: -0.3453 - binary_accuracy: 0.9963 - iou: 0.3451 - dice_coef: 0.5051 - val_loss: -0.3960 - val_binary_accuracy: 0.9943 - val_iou: 0.3830 - val_dice_coef: 0.5313
# Epoch 17/20
# 100/99 [==============================] - ETA: 0s - loss: -0.3941 - binary_accuracy: 0.9965 - iou: 0.3941 - dice_coef: 0.5579
# Epoch 17: val_loss improved from -0.39603 to -0.43487, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 34s 343ms/step - loss: -0.3941 - binary_accuracy: 0.9965 - iou: 0.3941 - dice_coef: 0.5579 - val_loss: -0.4349 - val_binary_accuracy: 0.9946 - val_iou: 0.4250 - val_dice_coef: 0.5861
# Epoch 18/20
# 100/99 [==============================] - ETA: 0s - loss: -0.4290 - binary_accuracy: 0.9963 - iou: 0.4302 - dice_coef: 0.5917
# Epoch 18: val_loss improved from -0.43487 to -0.48546, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 37s 369ms/step - loss: -0.4290 - binary_accuracy: 0.9963 - iou: 0.4302 - dice_coef: 0.5917 - val_loss: -0.4855 - val_binary_accuracy: 0.9946 - val_iou: 0.4895 - val_dice_coef: 0.6434
# Epoch 19/20
# 100/99 [==============================] - ETA: 0s - loss: -0.4929 - binary_accuracy: 0.9969 - iou: 0.4939 - dice_coef: 0.6549
# Epoch 19: val_loss improved from -0.48546 to -0.50672, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 36s 360ms/step - loss: -0.4929 - binary_accuracy: 0.9969 - iou: 0.4939 - dice_coef: 0.6549 - val_loss: -0.5067 - val_binary_accuracy: 0.9951 - val_iou: 0.4953 - val_dice_coef: 0.6406
# Epoch 20/20
# 100/99 [==============================] - ETA: 0s - loss: -0.5364 - binary_accuracy: 0.9971 - iou: 0.5372 - dice_coef: 0.6935
# Epoch 20: val_loss improved from -0.50672 to -0.57294, saving model to unet_128_mri_seg.hdf5
# 99/99 [==============================] - 33s 336ms/step - loss: -0.5364 - binary_accuracy: 0.9971 - iou: 0.5372 - dice_coef: 0.6935 - val_loss: -0.5729 - val_binary_accuracy: 0.9954 - val_iou: 0.5635 - val_dice_coef: 0.7075

# %%
results = model.evaluate(data_test, steps=len(mri_df_test) / BATCH_SIZE)

print("Test loss: ",round(results[0],3),
      "Test Binary Accuracy: ",round(results[1],3),
      "Test IOU: ",round(results[2],3),
      "Test Dice Coefficent: ",round(results[3],3))
# Out:
# Found 393 validated image filenames.
# Found 393 validated image filenames.
# 12/12 [==============================] - 4s 385ms/step - loss: -0.5257 - binary_accuracy: 0.9975 - iou: 0.5240 - dice_coef: 0.6782
# Test loss:  -0.526 Test Binary Accuracy:  0.997 Test IOU:  0.524 Test Dice Coefficent:  0.678

# %%
results = model.evaluate(data_test, steps=len(mri_df_test) / BATCH_SIZE)

test_loss = round(results[0], 3)
test_binary_accuracy = round(results[1] * 100, 3)
test_iou = round(results[2] * 100, 3)
test_dice_coefficient = round(results[3] * 100, 3)

print("Test loss:", test_loss,
      "Test Binary Accuracy:", test_binary_accuracy, "%",
      "Test IOU:", test_iou, "%",
      "Test Dice Coefficient:", test_dice_coefficient, "%")
# Out:
# 12/12 [==============================] - 3s 225ms/step - loss: -0.5302 - binary_accuracy: 0.9975 - iou: 0.5157 - dice_coef: 0.6702
# Test loss: -0.53 Test Binary Accuracy: 99.752 % Test IOU: 51.572 % Test Dice Coefficient: 67.024 %

# %%
for i in range(20):
    index=np.random.randint(1,len(mri_df_test.index))
    img = cv2.imread(mri_df_test['img'].iloc[index])
    img = cv2.resize(img ,(128, 128))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=model.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('True Image')
    plt.subplot(1,3,2)
    plt.imshow(np.squeeze(cv2.imread(mri_df_test['msk'].iloc[index])))
    plt.title('True Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
